# %% [markdown]
# # Task 3: Exploratory Data Analysis - Retail
#
# #      Author: Devraj Purna Visesh
#
# **Problem Statement**
#
# As a business manager, try to find out the weak areas where you can
# work to make more profit.

# %%
#Importing necessary Libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv(r'E:\Jupyter Notebook\SampleSuperstore.csv')
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Checking NULL values in Dataset

data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.duplicated().sum() #Checking the number of duplicate values
# Out:
# 17

# %%
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9977 rows x 13 columns]

# %%
data.nunique() #Unique values
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis
#
# **Checking Profits in different states**

# %%
print('total no. of states are: ', data['State'].nunique())
print(data['State'].value_counts())
# Out:
# total no. of states are:  49
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# South Carolina            42
# Louisiana                 42
# Nevada                    39
# Nebraska                  38
# New Mexico                37
# Iowa                      30
# New Hampshire             27
# Kansas                    24
# Idaho                     21
# Montana                   15
# South Dakota              12
# Vermont                   11
# District of Columbia      10
# Maine                      8
# North Dakota               7
# West Virginia              4
# Wyoming                    1
# Name: State, dtype: int64

# %%
States_profit = data.groupby('State').sum()['Profit'].sort_values(ascending=False).reset_index()
#Sorting the states by their profits in descending order from highest to lowest profit.

# %%
plt.figure(figsize=(15,10))
plt.title('Most Profitable States')
sns.barplot(x = 'State', y = 'Profit', data = States_profit.head(15)) #printing first 15 highest profitable states
plt.xticks(rotation = 60, fontsize = 15) #rorating the on x-axis
plt.yticks(fontsize = 15)
plt.show()

# %%
# Total states are 49, we found the most profitable 15 states no Now, Let's find out lowest profitable 15 states from remaining 34 states.

# %%
plt.figure(figsize=(15,10))
plt.title('Least Profitable States')
sns.barplot(x = 'State', y = 'Profit', data = States_profit.tail(15)) #printing first 15 Lowest profitable states
plt.xticks(rotation = 60, fontsize = 15) #rorating the on x-axis
plt.yticks(fontsize = 15)
plt.show()

# %% [markdown]
# **From the above chart we can predict that, state with highest profit is California and state with lowest profit is Texas**
#
# # Checking Profits in Different Cities

# %%
print('Total no. of Cities are : ', data['City'].nunique())
print(data['City'].value_counts())
# Out:
# Total no. of Cities are :  531
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Keller               1
# Citrus Heights       1
# San Mateo            1
# Commerce City        1
# Rochester Hills      1
# Name: City, Length: 531, dtype: int64

# %%
city_profit = data.groupby('City').sum()['Profit'].sort_values(ascending = False).reset_index()
#Grouping the cities to check the profits in each city and sorting them is descending order from highest to lowest profit.

# %%
plt.figure(figsize=(15,10))
plt.title('Most profitable Cities')
#sns.barplot(x = city_profit['City'][:15],y = city_profit['Profit'][:15])
sns.barplot(x = 'City', y = 'Profit', data = city_profit.head(15))
plt.xticks(rotation = 60, fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %% [markdown]
# **Here we can Predict that, City with highest profit is New York and city lowest profit is Philadelphia**
#
# # Checking Sales in Different States

# %%
State_sales = data.groupby('State').sum()['Sales'].sort_values(ascending = False).reset_index()

# %%
plt.figure(figsize=(15,10))
plt.title('States with Highest Sales Rate')
sns.barplot(x = 'State',y = 'Sales', data = State_sales.head(15))
plt.xticks(rotation = 60, fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title('States with lowest Sales Rate')
sns.barplot(x = 'State',y = 'Sales', data = State_sales.tail(15))
plt.xticks(rotation = 60, fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %% [markdown]
# **So From this we can Predict that the state having highest sales rate is California and State having Lowest sales rate  is North Dakota**
#
# # Sales vs Profit

# %%
Sales = data.groupby('State').sum()['Sales'].nlargest(n=15) # Top 15 States with highest sales
Profits = data.groupby('State').sum()['Profit'].nlargest(n=15) # Top 15 states with highest sales

Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color ='lightgreen')
Profits.plot(kind='bar', figsize=(10,5), fontsize = 15 , color='Purple')
plt.xlabel('States', fontsize =15)
plt.ylabel('Total sales and profit', fontsize =15)
plt.title("Sales vs Profit", fontsize= 15)
plt.show()

# %% [markdown]
# **From the plot above we can conclude that California and NewYork as Highest sales and Profits.**
#
# # profit and Sales on Different Categories

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Category', data = data)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %%
Category_profit = data.groupby('Category').sum()['Profit'].sort_values(ascending = False)

# %%
plt.figure(figsize=(6,6))
plt.title('Profit on different categories')
Category_profit.plot(kind = 'bar')
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
plt.show()

# %%
Sales = data.groupby('Category').sum()['Sales'].nlargest(n=15) # Top 15 States with highest sales
Profits = data.groupby('Category').sum()['Profit'].nlargest(n=15) # Top 15 states with highest sales

Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color ='lightgreen')
Profits.plot(kind='bar', figsize=(10,5), fontsize = 15 , color='Purple')
plt.xlabel('States', fontsize =15)
plt.ylabel('Total sales and profit', fontsize =15)
plt.title("Sales vs Profit", fontsize= 15)
plt.show()

# %% [markdown]
# **Here we can conclude that, Technology and Office supplies has the highest sales and profit**
#
# # Profits and Sales accordingly to Subcategory

# %%
data['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x = 'Sub-Category', data = data)
plt.xticks(rotation = 90, fontsize = 10)
plt.yticks(fontsize = 10)
plt.show()

# %%
Sc_profit = data.groupby('Sub-Category').mean()['Profit'].sort_values(ascending = False).reset_index()

# %%
plt.figure(figsize=(15,10))
plt.title('Profit on  Sub-categories')
sns.barplot(x = 'Sub-Category', y = 'Profit', data = Sc_profit)
plt.xticks(rotation = 90, fontsize = 10)
plt.yticks(fontsize = 10)
plt.show()

# %% [markdown]
# **Sub-Categories with highest loss**

# %%
min_profit = data.groupby('Sub-Category').min()['Profit'].sort_values()

# %%
plt.figure(figsize=(8,6))
min_profit.plot()
plt.title('Sub-categories with Highest loss')
plt.xticks(rotation = 60, fontsize = 10)
plt.yticks(fontsize = 15)
plt.show()

# %%
Sales = data.groupby('Sub-Category').sum()['Sales'].sort_values(ascending = False) 
Profits = data.groupby('Sub-Category').sum()['Profit'].sort_values(ascending = False) 
plt.style.use('seaborn')
Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color ='lightgreen')
Profits.plot(kind='bar', figsize=(10,5), fontsize = 15 , color='Purple')
plt.xlabel('Sub-Category', fontsize =15)
plt.ylabel('Total sales and profit', fontsize =15)
plt.title("Sales vs Profit", fontsize= 15)
plt.show()

# %% [markdown]
# **From above plots, we can conclude that Copiers Sub-Category shows highest profit with highest sales and Tables shows least profit sales**
#
# # Profit on ship modes

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x='Ship Mode', data =data)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
ship_modes_profit=data.groupby('Ship Mode').mean()['Profit'].sort_values(ascending = False).reset_index()
#Average profit

# %%
plt.figure(figsize=(10,8))
plt.title('Profits on Ship modes')
sns.barplot(x = 'Ship Mode', y = 'Profit', data= ship_modes_profit)
plt.xticks(rotation = 60, fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
ship_modes_discount = data.groupby('Ship Mode').sum()['Discount'].sort_values(ascending = False).reset_index()

plt.figure(figsize=(10,5))
plt.title('Discounts on Ship Modes')
sns.barplot(x = 'Ship Mode', y = 'Discount', data = ship_modes_discount)
plt.xticks(fontsize =13)
plt.yticks(fontsize =13)
plt.show()

# %% [markdown]
# **From above two plots we can conclude that Standard class gives more discounts snd shows less average profit**
#
# # Profit according to segment

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sns.countplot(x = 'Segment', data = data)
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
segment_profit=data.groupby('Segment').mean()['Profit'].sort_values(ascending = False).reset_index()

# %%
plt.figure(figsize=(8,5))
plt.title('Profits according to Segments')
sns.barplot(x = 'Segment', y = 'Profit', data= segment_profit)
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.show()

# %%
Sales = data.groupby('Segment').mean()['Sales'].sort_values(ascending = False) 
Profits = data.groupby('Segment').mean()['Profit'].sort_values(ascending = False) 
plt.style.use('seaborn')
Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color ='lightgreen')
Profits.plot(kind='bar', figsize=(10,5), fontsize = 15 , color='Purple')
plt.xlabel('Segment', fontsize =15)
plt.ylabel('Total sales and profit', fontsize =15)
plt.title("Sales vs Profit", fontsize= 15)
plt.show()

# %% [markdown]
# **From above plot we can conclude that, Home Office Segment has more profit and sales whereas Consumer Segment has less profit and less sales.**
#
# # Profit according to Regions

# %%
data['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
sns.countplot(x='Region', data = data)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
Sales = data.groupby('Region').sum()['Sales'].sort_values(ascending = False) 
Profits = data.groupby('Region').sum()['Profit'].sort_values(ascending = False) 
plt.style.use('seaborn')
Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color ='lightgreen')
Profits.plot(kind='bar', figsize=(10,5), fontsize = 15 , color='Purple')
plt.xlabel('Regions', fontsize =15)
plt.ylabel('Total sales and profit', fontsize =15)
plt.title("Sales vs Profit", fontsize= 15)
plt.show()

# %% [markdown]
# **From above plot we can conclude that, West Region has more profit and sales whereas Central Region has less profit and less sales.**
#
# # Checking the correlations

# %%
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# **From this Correlation we can conclude that the cities or states having highest disconts will give low profits and the cities/states with high sales will give high profits**

# %%
plt.style.use('seaborn')
data.plot(kind = "scatter", figsize =(10,5), x ="Sales", y = "Profit", c = "Discount", s= 20, fontsize = 16, colormap ="plasma")
plt.ylabel('Total Profits', fontsize = 15)
plt.title("Dependancy of Sales, profits and Discounts", fontsize = 15)
plt.show()

# %%
sns.lineplot(x='Sales', y='Profit', data = data)
plt.show()

# %%
sns.lineplot(x='Discount', y='Profit', data = data)
plt.show()

# %% [markdown]
# **Hence we can conclude that, Product sales increases with increase in Discounts but Profit decreases**
#
# # Conclusion :
#
# **1) The cities/ states which gives more discounts on products shows more sales but very less profit**
#
# **2) West region shows more sales and more profit whereas central region shows least sales and profits. So, we should try to increase sales and profits in central region.**
#
# **3) We should limit the discounts on standard class shipment and try to increase its sales and profits.**
#
# **4)Technology category shows more profit so, we should increase its sales and reduce the sales for furnitures due to low profits.**
#
# **5) Copiers sub-category shows more profit and tabels shows least profit so we should also reduce it's sales and increase sales for sub-categories like Accessories and phones.**
#
# **6) States showing high profit ratios are California and New York whereas States showing least profit ratios are Texas and Ohio.**
#
# **7)Cities showing high profit ratios are New-York and Los Angeles Whereas Cities Showing least profit ratios are Philidelphia and Housten.**
